# %%
import pandas as pd
import plotly.express as px

# %%
# read the data
# data originally from: https://www.kaggle.com/nagarajbhat/australian-bush-fire-satellite-data-nasa?select=fire_nrt_M6_101673.csv
df = pd.read_csv("https://intro-to-python-asdaf.s3.ap-southeast-2.amazonaws.com/fire_and_thermal_anomalies.csv")

# %%
# add a column for the color red 
df["color"] = "red"
df.head()
# Out:
#    latitude  longitude  brightness  scan  track    acq_date  acq_time  \
# 0   -18.411    145.322       334.8   1.3    1.1  2020-01-01        50
# 1   -18.420    145.308       346.6   1.3    1.1  2020-01-01        50
# 2   -18.422    145.321       340.9   1.3    1.1  2020-01-01        50
# 3   -18.438    145.281       338.1   1.3    1.1  2020-01-01        50
# 4   -18.439    145.293       331.3   1.3    1.1  2020-01-01        50
#
#   satellite instrument  confidence version  bright_t31   frp daynight color
# 0     Terra      MODIS          80  6.0NRT       306.2  33.2        D   red
# 1     Terra      MODIS          91  6.0NRT       307.7  61.7        D   red
# 2     Terra      MODIS          86  6.0NRT       306.6  47.0        D   red
# 3     Terra      MODIS          71  6.0NRT       309.2  34.9        D   red
# 4     Terra      MODIS          48  6.0NRT       307.5  22.5        D   red

# %%
# documentation for scatter_mapbox: https://plotly.github.io/plotly.py-docs/generated/plotly.express.scatter_mapbox.html
# turn the markers red by using the additional argument: color_discrete_sequence=df["color"]
fig = px.scatter_mapbox(df, lat="latitude", lon="longitude", size="brightness", zoom=3, size_max=10, mapbox_style="open-street-map", height=600, opacity=0.1, color_discrete_sequence=df["color"])
fig.update_layout(margin={"r":0,"t":0,"l":0,"b":0}) # set margins to 0 so that map is bigger
fig.show()
